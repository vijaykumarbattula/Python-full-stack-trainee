# %%
# string operations:
#concentation: two join two strings
vijay ="raju"
ravi ="kumar"
print(vijay + ravi)
# Out:
# rajukumar

# %%
king ="raju"
king2 ="kumar"
print(king+king2)
# Out:
# rajukumar

# %%
# repeation:
subbulu ="vijay"
print(subbulu*3)
# Out:
# vijayvijayvijay

# %%
# comparing two strings:
v=10
i =11
print(v==i)
print(v!=i)
print(v<i)
print(v>i)
# Out:
# False
# True
# True
# False

# %%
# in or not:
k = "kumar"
print(k in "m")
print( k not in "j")
# Out:
# False
# True

# %%
#string methods:
vijay = "VIJAYKUMAR"
print(vijay.upper()) # 1.upper()
print(vijay.lower()) # 2.lower()
print(vijay.capitalize()) #3.capitaliz
# Out:
# VIJAYKUMAR
# vijaykumar
# Vijaykumar

# %%
vijay= "raju"
print(vijay.title()) #4.
# Out:
# Raju

# %%
king =input(" enter a string")
print(king.split())
print(king.split("-"))
print(king.split(",")) #5.
# Out:
#  enter a string vijay-kumar
# ['vijay-kumar']
# ['vijay', 'kumar']
# ['vijay-kumar']

# %%
king = "vijaykumar"
print(king.endswith("ar")) #6
print(king.startswith("v")) #7
# Out:
# True
# True

# %%
king = "subbulu"
print(king.find("bbulu")) #8.
# Out:
# 2

# %%
king = "vijay"
print(king.isalpha()) #9.
king = "vijay123"
print(king.isalpha())
king = "12345"
print(king.isalpha())
# Out:
# True
# False
# False

# %%
raju ="lucky" #11.
print(raju.isdigit())
raju ="lucky123"
print(raju.isdigit())
raju ="123"
print(raju.isdigit())
# Out:
# False
# False
# True

# %%
# string replace(): #12.
king ="chinna"
print(king.replace("chinna" , "babu"))
# Out:
# babu

# %%
# 13 . isalnum(): 
king ="vijay123"
print(king.isalnum())
king ="vijay 123"
print(king.isalnum())
king ="123"
print(king.isalnum())
king ="vijay"
print(king.isalnum())
# Out:
# True
# False
# True
# True

# %%
# count(): # 14.
raju ="printt"
print(raju.count("t"))
# Out:
# 2
