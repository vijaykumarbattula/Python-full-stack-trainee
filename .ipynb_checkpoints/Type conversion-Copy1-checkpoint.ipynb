# %%
# interger to float , boolean , string
num = 10
print(float(num))
print(bool(num))
print(str(num))
print(complex(num))
# Out:
# 10.0
# True
# 10
# (10+0j)

# %%
num = 8
print(float(num))
print(bool(num))
print(str(num))
print(complex(num))
# Out:
# 8.0
# True
# 8
# (8+0j)

# %%
# float to int , bool, and string
val = 10.2556
num = int(val)
print(type(num) , num)
# Out:
# <class 'int'> 10

# %%
val = 10.2556
num = int(val)
print(type(num) , num)
print(bool(val))
str_val = str(val)
print(type(str_val) , str_val)
print(str_val[4])
print(str_val[1] , str_val[-1])
# Out:
# <class 'int'> 10
# True
# <class 'str'> 10.2556
# 5
# 0 6

# %%
val = 1102.25545521
strval = str(val)
ind = strval.find(',')
print(strval[:ind])
# Out:
# 1102.2554552

# %%
val = 1102.2554552
strval = str(val)
ind = strval.find(',')
print(strval[:ind])
# Out:
# 1102.255455

# %%
# in boolean value int , float
b = True
print(int(b))
print(float(b))
# Out:
# 1
# 1.0

# %%
# string to int , float , bool, list , tuple , set
# if string value is number
s = '123456'
print(int(s))
print(float(s))
print(bool(s))
print(list(s))
print(tuple(s))
print(set(s))
# Out:
# 123456
# 123456.0
# True
# ['1', '2', '3', '4', '5', '6']
# ('1', '2', '3', '4', '5', '6')
# {'4', '1', '6', '2', '3', '5'}

# %%
# string to int , float , bool, list , tuple , set
# if string value is float
s = '123456.1205'
print(int(float(s))) #
print(float(s))
print(bool(s))
print(list(s))
print(tuple(s))
print(set(s))
# Out:
# 123456
# 123456.1205
# True
# ['1', '2', '3', '4', '5', '6', '.', '1', '2', '0', '5']
# ('1', '2', '3', '4', '5', '6', '.', '1', '2', '0', '5')
# {'4', '.', '1', '6', '2', '3', '0', '5'}
