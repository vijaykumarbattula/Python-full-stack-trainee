# %%
text ="a,b,c,d"
print(len(text.split(",")))
# Out:
# 4

# %%
text = "banana"
print(text[1:text.find("na")]) # slicing[ 1:2] is "a"
# Out:
# a

# %%
text = "banana"
print(text.find("na") + text.count("a") )
# Out:
# 5
